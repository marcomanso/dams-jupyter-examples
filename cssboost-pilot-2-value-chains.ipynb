# %% [markdown]
# # ANALYSIS FOR CARRIS DATA - PILOT 4 DATASET

# %%
start_date="2023-01-01"
end_date="2027-01-01"
#start_date="2025-01-01"
#end_date="2025-07-31"

# %%
#!pip install matplotlib
#!pip install pandas

# %%
import common as common
import common_test as common_test

# %%
import json

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#API_SERVER="https://api.cssboost.particle-summary.pt"
API_SERVER="https://api.cssboost.particle-summary.pt"

# %%
token="..."

# %%
# check valid token
ENDPOINT_USER=API_SERVER+"/rest-auth/user"
(result, data)=common.get_data(ENDPOINT_USER, token, None)
# Out:
# -- get from  https://api.cssboost.particle-summary.pt/rest-auth/user
# -- data GET OK.

# %%
if result == 200:
    print("-- result OK ", result, data)
else:
    raise SystemExit("-- token invalid? result NOK. code=", result)
# Out:
# -- result OK  200 {'pk': 4, 'username': 'particle@particle-summary.pt', 'email': 'particle@particle-summary.pt', 'first_name': 'PARTICLE', 'last_name': '', 'person_external_id': 'b938ed21-7819-41ef-9105-62790ee32fb0'}

# %% [markdown]
# # Value chains

# %% [markdown]
# Operations related with value chains below.
# Pilot 4 will be used for queries involving filtering.

# %%
ENDPOINT_GET_ALL_CHAINS=API_SERVER+"/value-chains"
PILOT="pilot_2"

# %%
(result, data)=common.get_data(ENDPOINT_GET_ALL_CHAINS, token, None)
# Out:
# -- get from  https://api.cssboost.particle-summary.pt/value-chains
# -- data GET OK.

# %%
print(json.dumps(data, indent=2))
# Out:
# {
#   "items": [
#     {
#       "external_id": "pilot_2_vc_2",
#       "name": "2 - WW for nutrients",
#       "description": "Wastewater reuse for nutrients in agriculture",
#       "active": true,
#       "pilot_external_id": "pilot_2"
#     },
#     {
#       "external_id": "pilot_2_vc_1",
#       "name": "1 - WW for reuse",
#       "description": "Wastewater for reuse in crop irrigation and nature restoration",
#       "active": true,
#       "pilot_external_id": "pilot_2"
#     },
#     {
#       "external_id": "pilot_4_vc_1",
#       "name": "VC1: Sustainable Vehicle Production",
#       "description": "VC1 addresses the increase of added-value greener buses and increasing the percentage of recyclable materials in new buses designed and produced.",
#       "active": true,
#       "pilot_external_id": "pilot_4"
#     },
#     {
#       "external_id": "pilot_4_vc_2",
#       "name": "VC2: Bus Service Life",
# ...

# %%
ENDPOINT_GET_ALL_CHAINS_FROM_PILOT=API_SERVER+"/value-chains?pilot_external_id="+PILOT
(result, data)=common.get_data(ENDPOINT_GET_ALL_CHAINS_FROM_PILOT, token, None)
print(json.dumps(data, indent=2))
# Out:
# -- get from  https://api.cssboost.particle-summary.pt/value-chains?pilot_external_id=pilot_2
# -- data GET OK.
# {
#   "items": [
#     {
#       "external_id": "pilot_2_vc_2",
#       "name": "2 - WW for nutrients",
#       "description": "Wastewater reuse for nutrients in agriculture",
#       "active": true,
#       "pilot_external_id": "pilot_2"
#     },
#     {
#       "external_id": "pilot_2_vc_1",
#       "name": "1 - WW for reuse",
#       "description": "Wastewater for reuse in crop irrigation and nature restoration",
#       "active": true,
#       "pilot_external_id": "pilot_2"
#     }
#   ],
#   "count": 2
# }

# %% [markdown]
# ## Value chain objects

# %% [markdown]
# It is also possible to find all objects associated to a value chain.

# %%
VALUE_CHAIN_ID="pilot_2_vc_1"

# %%
ENDPOINT_GET_ALL_SOURCES_FROM_PILOT=API_SERVER+"/value-chains/"+VALUE_CHAIN_ID+"/data-sources"
(result, data)=common.get_data(ENDPOINT_GET_ALL_SOURCES_FROM_PILOT, token, None)
print(json.dumps(data, indent=2))
# Out:
# -- get from  https://api.cssboost.particle-summary.pt/value-chains/pilot_2_vc_1/data-sources
# -- data GET OK.
# {
#   "items": [
#     {
#       "external_id": "pilot_2_dataset_1_PTREF00005",
#       "name": "P2-DS1-PTREF00005",
#       "description": "Laboratory analysis: Point of reference for POZZETTO INGRESSO",
#       "value_chain_id": "pilot_2_vc_1",
#       "supply_chain_id": null,
#       "source_external_id": "PTREF00005",
#       "source": {
#         "name": "POZZETTO INGRESSO",
#         "state": "ACTIVE",
#         "valueType": "PUBLIC",
#         "macAddress": null,
#         "serialNumber": null,
#         "deviceId": "PTREF00005",
#         "externalId": "PTREF00005",
#         "deviceType": "report_source"
#       }
#     },
#     {
#       "external_id": "pilot_2_dataset_1_PTREF00006",
#       "name": "PTREF00006",
#       "description": "Laboratory analysis: Point of reference for POZZETTO USCITA",
#       "value_chain_id": "pilot_2_vc_1",
# ...

# %%
ENDPOINT_GET_ALL_SOURCES_FROM_PILOT=API_SERVER+"/value-chains/"+VALUE_CHAIN_ID+"/devices"
(result, data)=common.get_data(ENDPOINT_GET_ALL_SOURCES_FROM_PILOT, token, None)
print(json.dumps(data, indent=2))
# Out:
# -- get from  https://api.cssboost.particle-summary.pt/value-chains/pilot_2_vc_1/devices
# -- data GET OK.
# {
#   "items": [
#     {
#       "external_id": "pilot_2_dataset_1_CDEPUR00198DESB67_MISU10_MFPOR1",
#       "name": "CDEPUR00198DESB67_MISU10_MFPOR1",
#       "description": "CDEPUR00198DESB67_MISU10_MFPOR1",
#       "value_chain_id": "pilot_2_vc_1",
#       "supply_chain_id": null,
#       "device_external_id": "CDEPUR00198DESB67_MISU10_MFPOR1",
#       "device": {
#         "name": "CDEPUR00198DESB67_MISU10_MFPOR1",
#         "state": "ACTIVE",
#         "valueType": "PUBLIC",
#         "macAddress": null,
#         "serialNumber": "CDEPUR00198DESB67_MISU10_MFPOR1",
#         "deviceId": "CDEPUR00198DESB67_MISU10_MFPOR1",
#         "externalId": "CDEPUR00198DESB67_MISU10_MFPOR1",
#         "deviceType": "flow_sensor"
#       }
#     },
#     {
#       "external_id": "pilot_2_dataset_1_CDEPUR00198DESB67_MISU11_MFPOR1",
#       "name": "CDEPUR00198DESB67_MISU11_MFPOR1",
# ...

# %%
ENDPOINT_GET_ALL_SOURCES_FROM_PILOT=API_SERVER+"/value-chains/"+VALUE_CHAIN_ID+"/files"
(result, data)=common.get_data(ENDPOINT_GET_ALL_SOURCES_FROM_PILOT, token, None)
print(json.dumps(data, indent=2))
# Out:
# -- get from  https://api.cssboost.particle-summary.pt/value-chains/pilot_2_vc_1/files
# -- data GET OK.
# {
#   "items": [],
#   "count": 0
# }

# %%
ENDPOINT_GET_ALL_SOURCES_FROM_PILOT=API_SERVER+"/value-chains/"+VALUE_CHAIN_ID+"/urls"
(result, data)=common.get_data(ENDPOINT_GET_ALL_SOURCES_FROM_PILOT, token, None)
print(json.dumps(data, indent=2))
# Out:
# -- get from  https://api.cssboost.particle-summary.pt/value-chains/pilot_2_vc_1/urls
# -- data GET OK.
# {
#   "items": [],
#   "count": 0
# }

# %% [markdown]
# In addition, objects can be filtered by dataset.

# %%
DATASET="pilot_2_dataset_1"
ENDPOINT_GET_ALL_SOURCES_FROM_PILOT=API_SERVER+"/value-chains/"+VALUE_CHAIN_ID+"/data-sources?dataset_external_id="+DATASET
(result, data)=common.get_data(ENDPOINT_GET_ALL_SOURCES_FROM_PILOT, token, None)
print(json.dumps(data, indent=2))
# Out:
# -- get from  https://api.cssboost.particle-summary.pt/value-chains/pilot_2_vc_1/data-sources?dataset_external_id=pilot_2_dataset_1
# -- data GET OK.
# {
#   "items": [
#     {
#       "external_id": "pilot_2_dataset_1_PTREF00005",
#       "name": "P2-DS1-PTREF00005",
#       "description": "Laboratory analysis: Point of reference for POZZETTO INGRESSO",
#       "value_chain_id": "pilot_2_vc_1",
#       "supply_chain_id": null,
#       "source_external_id": "PTREF00005",
#       "source": {
#         "name": "POZZETTO INGRESSO",
#         "state": "ACTIVE",
#         "valueType": "PUBLIC",
#         "macAddress": null,
#         "serialNumber": null,
#         "deviceId": "PTREF00005",
#         "externalId": "PTREF00005",
#         "deviceType": "report_source"
#       }
#     },
#     {
#       "external_id": "pilot_2_dataset_1_PTREF00006",
#       "name": "PTREF00006",
#       "description": "Laboratory analysis: Point of reference for POZZETTO USCITA",
# ...

# %%
DATASET="pilot_2_dataset_1"
ENDPOINT_GET_ALL_SOURCES_FROM_PILOT=API_SERVER+"/value-chains/"+VALUE_CHAIN_ID+"/devices?dataset_external_id="+DATASET
(result, data)=common.get_data(ENDPOINT_GET_ALL_SOURCES_FROM_PILOT, token, None)
print(json.dumps(data, indent=2))
# Out:
# -- get from  https://api.cssboost.particle-summary.pt/value-chains/pilot_2_vc_1/devices?dataset_external_id=pilot_2_dataset_1
# -- data GET OK.
# {
#   "items": [
#     {
#       "external_id": "pilot_2_dataset_1_CDEPUR00198DESB67_MISU10_MFPOR1",
#       "name": "CDEPUR00198DESB67_MISU10_MFPOR1",
#       "description": "CDEPUR00198DESB67_MISU10_MFPOR1",
#       "value_chain_id": "pilot_2_vc_1",
#       "supply_chain_id": null,
#       "device_external_id": "CDEPUR00198DESB67_MISU10_MFPOR1",
#       "device": {
#         "name": "CDEPUR00198DESB67_MISU10_MFPOR1",
#         "state": "ACTIVE",
#         "valueType": "PUBLIC",
#         "macAddress": null,
#         "serialNumber": "CDEPUR00198DESB67_MISU10_MFPOR1",
#         "deviceId": "CDEPUR00198DESB67_MISU10_MFPOR1",
#         "externalId": "CDEPUR00198DESB67_MISU10_MFPOR1",
#         "deviceType": "flow_sensor"
#       }
#     },
#     {
#       "external_id": "pilot_2_dataset_1_CDEPUR00198DESB67_MISU11_MFPOR1",
# ...

# %%
DATASET="pilot_2_dataset_low_res"
ENDPOINT_GET_ALL_SOURCES_FROM_PILOT=API_SERVER+"/value-chains/"+VALUE_CHAIN_ID+"/devices?dataset_external_id="+DATASET
(result, data)=common.get_data(ENDPOINT_GET_ALL_SOURCES_FROM_PILOT, token, None)
print(json.dumps(data, indent=2))
# Out:
# -- get from  https://api.cssboost.particle-summary.pt/value-chains/pilot_2_vc_1/devices?dataset_external_id=pilot_2_dataset_low_res
# -- data GET OK.
# {
#   "items": [
#     {
#       "external_id": "pilot_2_dataset_1_CDEPUR00198DESB67_MISU10_MFPOR1",
#       "name": "CDEPUR00198DESB67_MISU10_MFPOR1",
#       "description": "CDEPUR00198DESB67_MISU10_MFPOR1",
#       "value_chain_id": "pilot_2_vc_1",
#       "supply_chain_id": null,
#       "device_external_id": "CDEPUR00198DESB67_MISU10_MFPOR1",
#       "device": {
#         "name": "CDEPUR00198DESB67_MISU10_MFPOR1",
#         "state": "ACTIVE",
#         "valueType": "PUBLIC",
#         "macAddress": null,
#         "serialNumber": "CDEPUR00198DESB67_MISU10_MFPOR1",
#         "deviceId": "CDEPUR00198DESB67_MISU10_MFPOR1",
#         "externalId": "CDEPUR00198DESB67_MISU10_MFPOR1",
#         "deviceType": "flow_sensor"
#       }
#     },
#     {
#       "external_id": "pilot_2_dataset_1_CDEPUR00198DESB67_MISU11_MFPOR1",
# ...
