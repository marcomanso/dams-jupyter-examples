# %% [markdown]
# # ANALYSIS FOR CARRIS DATA - PILOT 4 DATASET

# %%
start_date="2023-01-01"
end_date="2027-01-01"
#start_date="2025-01-01"
#end_date="2025-07-31"

# %%
#!pip install matplotlib
#!pip install pandas

# %%
import common as common
import common_test as common_test

# %%
import json

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
API_SERVER="https://api.cssboost.particle-summary.pt"
#API_SERVER="https://test.api.cssboost.particle-summary.pt"

# %%
token="..."

# %%
# check valid token
ENDPOINT_USER=API_SERVER+"/rest-auth/user"
(result, data)=common.get_data(ENDPOINT_USER, token, None)
# Out:
# -- get from  https://test.api.cssboost.particle-summary.pt/rest-auth/user
# -- data GET OK.

# %%
if result == 200:
    print("-- result OK ", result, data)
else:
    raise SystemExit("-- token invalid? result NOK. code=", result)
# Out:
# -- result OK  200 {'pk': 2, 'username': 'particle+admin@particle-summary.pt', 'email': 'particle+admin@particle-summary.pt', 'first_name': 'particlesummary', 'last_name': 'User', 'person_external_id': '5813eb25-0e31-4f09-9c45-56e01697498b'}

# %% [markdown]
# # Value chains

# %% [markdown]
# Operations related with value chains below.
# Pilot 4 will be used for queries involving filtering.

# %%
ENDPOINT_GET_ALL_CHAINS=API_SERVER+"/value-chains"
PILOT="pilot_4"

# %%
(result, data)=common.get_data(ENDPOINT_GET_ALL_CHAINS, token, None)
# Out:
# -- get from  https://test.api.cssboost.particle-summary.pt/value-chains
# -- data GET OK.

# %%
print(json.dumps(data, indent=2))
# Out:
# {
#   "items": [
#     {
#       "external_id": "pilot_4_vc_1",
#       "name": "VC1: Sustainable Vehicle Production",
#       "description": "VC1 addresses the increase of added-value greener buses and increasing the percentage of recyclable materials in new buses designed and produced.",
#       "active": true,
#       "pilot_external_id": "pilot_4"
#     },
#     {
#       "external_id": "pilot_4_vc_2",
#       "name": "VC2: Bus Service Life",
#       "description": "VC2 addresses the reduction of energy consumption, reduction of GHG emissions and reduction of waste",
#       "active": true,
#       "pilot_external_id": "pilot_4"
#     },
#     {
#       "external_id": "pilot_4_vc_3",
#       "name": "VC3: Vehicle End-of-Life Material Recovery",
#       "description": "VC3 addresses the reduction of waste of end-of-life vehicles, the increase in the valuation rate of residues and the increase of the re-use and recycling of under-valued assets.",
#       "active": true,
#       "pilot_external_id": "pilot_4"
#     },
#     {
#       "external_id": "pilot_2_vc_1",
#       "name": "1 - WW for reuse",
#       "description": "Value chain 1 - wastewater for reuse",
#       "active": true,
#       "pilot_external_id": "pilot_2"
#     },
#     {
#       "external_id": "pilot_2_vc_2",
#       "name": "2 - WW for nutrients",
#       "description": "Value chain 2 - wastewater for nutrients",
#       "active": true,
#       "pilot_external_id": "pilot_2"
#     }
#   ],
#   "count": 5
# }

# %%
ENDPOINT_GET_ALL_CHAINS_FROM_PILOT=API_SERVER+"/value-chains?pilot_external_id="+PILOT
(result, data)=common.get_data(ENDPOINT_GET_ALL_CHAINS_FROM_PILOT, token, None)
print(json.dumps(data, indent=2))
# Out:
# -- get from  https://test.api.cssboost.particle-summary.pt/value-chains?pilot_external_id=pilot_4
# -- data GET OK.
# {
#   "items": [
#     {
#       "external_id": "pilot_4_vc_1",
#       "name": "VC1: Sustainable Vehicle Production",
#       "description": "VC1 addresses the increase of added-value greener buses and increasing the percentage of recyclable materials in new buses designed and produced.",
#       "active": true,
#       "pilot_external_id": "pilot_4"
#     },
#     {
#       "external_id": "pilot_4_vc_2",
#       "name": "VC2: Bus Service Life",
#       "description": "VC2 addresses the reduction of energy consumption, reduction of GHG emissions and reduction of waste",
#       "active": true,
#       "pilot_external_id": "pilot_4"
#     },
#     {
#       "external_id": "pilot_4_vc_3",
#       "name": "VC3: Vehicle End-of-Life Material Recovery",
#       "description": "VC3 addresses the reduction of waste of end-of-life vehicles, the increase in the valuation rate of residues and the increase of the re-use and recycling of under-valued assets.",
#       "active": true,
#       "pilot_external_id": "pilot_4"
#     }
#   ],
#   "count": 3
# }

# %% [markdown]
# ## Value chain objects

# %% [markdown]
# It is also possible to find all objects associated to a value chain.

# %%
VALUE_CHAIN_ID="pilot_4_vc_2"

# %%
ENDPOINT_GET_ALL_SOURCES_FROM_PILOT=API_SERVER+"/value-chains/"+VALUE_CHAIN_ID+"/data-sources"
(result, data)=common.get_data(ENDPOINT_GET_ALL_SOURCES_FROM_PILOT, token, None)
print(json.dumps(data, indent=2))
# Out:
# -- get from  https://test.api.cssboost.particle-summary.pt/value-chains/pilot_4_vc_2/data-sources
# -- data GET OK.
# {
#   "items": [
#     {
#       "external_id": "pilot_4_dataset_1_MAN_GNC_BUS",
#       "name": "MAN_GNC_BUS",
#       "description": "Reports related with MAN 18.310 GNC",
#       "value_chain_id": "pilot_4_vc_2",
#       "supply_chain_id": null,
#       "source_external_id": "MAN_GNC_BUS",
#       "source": {
#         "name": "MAN 18.310 GNC Natural Gas Bus",
#         "state": "ACTIVE",
#         "valueType": "PUBLIC",
#         "macAddress": null,
#         "serialNumber": null,
#         "deviceId": "MAN_GNC_BUS",
#         "externalId": "MAN_GNC_BUS",
#         "deviceType": "report_source"
#       }
#     },
#     {
#       "external_id": "pilot_4_dataset_1_VOLVO_DIESEL_BUS",
#       "name": "VOLVO_DIESEL_BUS",
#       "description": "Reports related with VOLVO B7R MK3",
#       "value_chain_id": "pilot_4_vc_2",
#       "supply_chain_id": null,
#       "source_external_id": "VOLVO_DIESEL_BUS",
#       "source": {
#         "name": "VOLVO B7R MK3 Diesel Bus",
#         "state": "ACTIVE",
#         "valueType": "PUBLIC",
#         "macAddress": null,
#         "serialNumber": null,
#         "deviceId": "VOLVO_DIESEL_BUS",
#         "externalId": "VOLVO_DIESEL_BUS",
#         "deviceType": "report_source"
#       }
#     },
#     {
#       "external_id": "pilot_4_dataset_1_CAETANO_ELECTRIC_BUS",
#       "name": "CAETANO_ELECTRIC_BUS",
#       "description": "Reports related with CAETANO E. 28th AQ",
#       "value_chain_id": "pilot_4_vc_2",
#       "supply_chain_id": null,
#       "source_external_id": "CAETANO_ELECTRIC_BUS",
#       "source": {
#         "name": "CAETANO E. Electric Bus",
#         "state": "ACTIVE",
#         "valueType": "PUBLIC",
#         "macAddress": null,
#         "serialNumber": null,
#         "deviceId": "CAETANO_ELECTRIC_BUS",
#         "externalId": "CAETANO_ELECTRIC_BUS",
#         "deviceType": "report_source"
#       }
#     }
#   ],
#   "count": 3
# }

# %%
ENDPOINT_GET_ALL_SOURCES_FROM_PILOT=API_SERVER+"/value-chains/"+VALUE_CHAIN_ID+"/devices"
(result, data)=common.get_data(ENDPOINT_GET_ALL_SOURCES_FROM_PILOT, token, None)
print(json.dumps(data, indent=2))
# Out:
# -- get from  https://test.api.cssboost.particle-summary.pt/value-chains/pilot_4_vc_2/devices
# -- data GET OK.
# {
#   "items": [],
#   "count": 0
# }

# %%
ENDPOINT_GET_ALL_SOURCES_FROM_PILOT=API_SERVER+"/value-chains/"+VALUE_CHAIN_ID+"/files"
(result, data)=common.get_data(ENDPOINT_GET_ALL_SOURCES_FROM_PILOT, token, None)
print(json.dumps(data, indent=2))
# Out:
# -- get from  https://test.api.cssboost.particle-summary.pt/value-chains/pilot_4_vc_2/files
# -- data GET OK.
# {
#   "items": [],
#   "count": 0
# }

# %%
ENDPOINT_GET_ALL_SOURCES_FROM_PILOT=API_SERVER+"/value-chains/"+VALUE_CHAIN_ID+"/urls"
(result, data)=common.get_data(ENDPOINT_GET_ALL_SOURCES_FROM_PILOT, token, None)
print(json.dumps(data, indent=2))
# Out:
# -- get from  https://test.api.cssboost.particle-summary.pt/value-chains/pilot_4_vc_2/urls
# -- data GET OK.
# {
#   "items": [],
#   "count": 0
# }

# %% [markdown]
# In addition, objects can be filtered by dataset.

# %%
DATASET=""
ENDPOINT_GET_ALL_SOURCES_FROM_PILOT=API_SERVER+"/value-chains/"+VALUE_CHAIN_ID+"/data-sources"
(result, data)=common.get_data(ENDPOINT_GET_ALL_SOURCES_FROM_PILOT, token, None)
print(json.dumps(data, indent=2))
